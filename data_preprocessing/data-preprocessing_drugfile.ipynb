# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
my_data = pd.read_csv("drug200.csv")
my_data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
for item in my_data.columns:
    missing_values = my_data[item].isnull().sum()
    missing_data = missing_values/len(item) * 100
    print("There are {}% missing values in column {}".format(missing_data, item))
# Out:
# There are 0.0% missing values in column Age
# There are 0.0% missing values in column Sex
# There are 0.0% missing values in column BP
# There are 0.0% missing values in column Cholesterol
# There are 0.0% missing values in column Na_to_K
# There are 0.0% missing values in column Drug

# %%
x = my_data.iloc[:, :-1].values
y = my_data.iloc[:, -1].values
# Out:
# array([['F', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'LOW', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'LOW', 'HIGH'],
#        ['M', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['M', 'LOW', 'NORMAL'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'NORMAL', 'HIGH'],
#        ['F', 'LOW', 'NORMAL'],
#        ['F', 'HIGH', 'NORMAL'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'NORMAL', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'NORMAL'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'HIGH', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['F', 'HIGH', 'HIGH'],
#        ['F', 'LOW', 'HIGH'],
#        ['M', 'LOW', 'HIGH'],
#        ['M', 'NORMAL', 'HIGH'],
#        ['M', 'NORMAL', 'NORMAL'],
#        ['F', 'LOW', 'NORMAL']], dtype=object)

# %% [markdown]
# # Encode independent variable (X)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for i in range(1, 4):
    x[:, i] = le.fit_transform(x[:, i])
x
# Out:
# array([[23, 0, 0, 0, 25.355],
#        [47, 1, 1, 0, 13.093],
#        [47, 1, 1, 0, 10.114],
#        [28, 0, 2, 0, 7.798],
#        [61, 0, 1, 0, 18.043],
#        [22, 0, 2, 0, 8.607],
#        [49, 0, 2, 0, 16.275],
#        [41, 1, 1, 0, 11.037],
#        [60, 1, 2, 0, 15.171],
#        [43, 1, 1, 1, 19.368],
#        [47, 0, 1, 0, 11.767],
#        [34, 0, 0, 1, 19.199],
#        [43, 1, 1, 0, 15.376],
#        [74, 0, 1, 0, 20.942],
#        [50, 0, 2, 0, 12.703],
#        [16, 0, 0, 1, 15.516],
#        [69, 1, 1, 1, 11.455],
#        [43, 1, 0, 0, 13.972],
#        [23, 1, 1, 0, 7.298],
#        [32, 0, 0, 1, 25.974],
#        [57, 1, 1, 1, 19.128],
#        [63, 1, 2, 0, 25.917],
#        [47, 1, 1, 1, 30.568],
#        [48, 0, 1, 0, 15.036],
#        [33, 0, 1, 0, 33.486],
#        [28, 0, 0, 1, 18.809],
#        [31, 1, 0, 0, 30.366],
#        [49, 0, 2, 1, 9.381],
#        [39, 0, 1, 1, 22.697],
#        [45, 1, 1, 0, 17.951],
#        [18, 0, 2, 1, 8.75],
#        [74, 1, 0, 0, 9.567],
#        [49, 1, 1, 1, 11.014],
#        [65, 0, 0, 1, 31.876],
#        [53, 1, 2, 0, 14.133],
#        [46, 1, 2, 1, 7.285],
#        [32, 1, 0, 1, 9.445],
#        [39, 1, 1, 1, 13.938],
#        [39, 0, 2, 1, 9.709],
#        [15, 1, 2, 0, 9.084],
#        [73, 0, 2, 0, 19.221],
#        [58, 0, 0, 1, 14.239],
#        [50, 1, 2, 1, 15.79],
#        [23, 1, 2, 0, 12.26],
#        [50, 0, 2, 1, 12.295],
#        [66, 0, 2, 1, 8.107],
#        [37, 0, 0, 0, 13.091],
#        [68, 1, 1, 0, 10.291],
#        [23, 1, 2, 0, 31.686],
#        [28, 0, 1, 0, 19.796],
#        [58, 0, 0, 0, 19.416],
#        [67, 1, 2, 1, 10.898],
#        [62, 1, 1, 1, 27.183],
#        [24, 0, 0, 1, 18.457],
#        [68, 0, 0, 1, 10.189],
#        [26, 0, 1, 0, 14.16],
#        [65, 1, 0, 1, 11.34],
#        [40, 1, 0, 0, 27.826],
#        [60, 1, 2, 1, 10.091],
#        [34, 1, 0, 0, 18.703],
#        [38, 0, 1, 1, 29.875],
#        [24, 1, 0, 1, 9.475],
#        [67, 1, 1, 1, 20.693],
#        [45, 1, 1, 1, 8.37],
#        [60, 0, 0, 0, 13.303],
#        [68, 0, 2, 1, 27.05],
#        [29, 1, 0, 0, 12.856],
#        [17, 1, 2, 1, 10.832],
#        [54, 1, 2, 0, 24.658],
#        [18, 0, 0, 1, 24.276],
#        [70, 1, 0, 0, 13.967],
#        [28, 0, 2, 0, 19.675],
#        [24, 0, 2, 0, 10.605],
#        [41, 0, 2, 1, 22.905],
#        [31, 1, 0, 1, 17.069],
#        [26, 1, 1, 1, 20.909],
#        [36, 0, 0, 0, 11.198],
#        [26, 0, 0, 1, 19.161],
#        [19, 0, 0, 0, 13.313],
#        [32, 0, 1, 1, 10.84],
#        [60, 1, 0, 0, 13.934],
#        [64, 1, 2, 0, 7.761],
#        [32, 0, 1, 0, 9.712],
#        [38, 0, 0, 1, 11.326],
#        [47, 0, 1, 0, 10.067],
#        [59, 1, 0, 0, 13.935],
#        [51, 0, 2, 0, 13.597],
#        [69, 1, 1, 0, 15.478],
#        [37, 0, 0, 1, 23.091],
#        [50, 0, 2, 1, 17.211],
#        [62, 1, 2, 0, 16.594],
#        [41, 1, 0, 1, 15.156],
#        [29, 0, 0, 0, 29.45],
#        [42, 0, 1, 1, 29.271],
#        [56, 1, 1, 0, 15.015],
#        [36, 1, 1, 1, 11.424],
#        [58, 0, 1, 0, 38.247],
#        [56, 0, 0, 0, 25.395],
#        [20, 1, 0, 1, 35.639],
#        [15, 0, 0, 1, 16.725],
#        [31, 1, 0, 1, 11.871],
#        [45, 0, 0, 0, 12.854],
#        [28, 0, 1, 0, 13.127],
#        [56, 1, 2, 0, 8.966],
#        [22, 1, 0, 1, 28.294],
#        [37, 1, 1, 1, 8.968],
#        [22, 1, 2, 0, 11.953],
#        [42, 1, 1, 0, 20.013],
#        [72, 1, 0, 1, 9.677],
#        [23, 1, 2, 0, 16.85],
#        [50, 1, 0, 0, 7.49],
#        [47, 0, 2, 1, 6.683],
#        [35, 1, 1, 1, 9.17],
#        [65, 0, 1, 1, 13.769],
#        [20, 0, 2, 1, 9.281],
#        [51, 1, 0, 0, 18.295],
#        [67, 1, 2, 1, 9.514],
#        [40, 0, 2, 0, 10.103],
#        [32, 0, 0, 1, 10.292],
#        [61, 0, 0, 0, 25.475],
#        [28, 1, 2, 0, 27.064],
#        [15, 1, 0, 1, 17.206],
#        [34, 1, 2, 0, 22.456],
#        [36, 0, 2, 0, 16.753],
#        [53, 0, 0, 1, 12.495],
#        [19, 0, 0, 1, 25.969],
#        [66, 1, 0, 0, 16.347],
#        [35, 1, 2, 1, 7.845],
#        [47, 1, 1, 1, 33.542],
#        [32, 0, 2, 0, 7.477],
#        [70, 0, 2, 0, 20.489],
#        [52, 1, 1, 1, 32.922],
#        [49, 1, 1, 1, 13.598],
#        [24, 1, 2, 0, 25.786],
#        [42, 0, 0, 0, 21.036],
#        [74, 1, 1, 1, 11.939],
#        [55, 0, 0, 0, 10.977],
#        [35, 0, 0, 0, 12.894],
#        [51, 1, 0, 1, 11.343],
#        [69, 0, 2, 0, 10.065],
#        [49, 1, 0, 1, 6.269],
#        [64, 0, 1, 1, 25.741],
#        [60, 1, 0, 1, 8.621],
#        [74, 1, 0, 1, 15.436],
#        [39, 1, 0, 0, 9.664],
#        [61, 1, 2, 0, 9.443],
#        [37, 0, 1, 1, 12.006],
#        [26, 0, 0, 1, 12.307],
#        [61, 0, 1, 1, 7.34],
#        [22, 1, 1, 0, 8.151],
#        [49, 1, 0, 1, 8.7],
#        [68, 1, 0, 0, 11.009],
#        [55, 1, 2, 1, 7.261],
#        [72, 0, 1, 1, 14.642],
#        [37, 1, 1, 1, 16.724],
#        [49, 1, 1, 0, 10.537],
#        [31, 1, 0, 1, 11.227],
#        [53, 1, 1, 0, 22.963],
#        [59, 0, 1, 0, 10.444],
#        [34, 0, 1, 1, 12.923],
#        [30, 0, 2, 0, 10.443],
#        [57, 0, 0, 1, 9.945],
#        [43, 1, 2, 1, 12.859],
#        [21, 0, 0, 1, 28.632],
#        [16, 1, 0, 1, 19.007],
#        [38, 1, 1, 0, 18.295],
#        [58, 0, 1, 0, 26.645],
#        [57, 0, 2, 0, 14.216],
#        [51, 0, 1, 1, 23.003],
#        [20, 0, 0, 0, 11.262],
#        [28, 0, 2, 0, 12.879],
#        [45, 1, 1, 1, 10.017],
#        [39, 0, 2, 1, 17.225],
#        [41, 0, 1, 1, 18.739],
#        [42, 1, 0, 1, 12.766],
#        [73, 0, 0, 0, 18.348],
#        [48, 1, 0, 1, 10.446],
#        [25, 1, 2, 0, 19.011],
#        [39, 1, 2, 0, 15.969],
#        [67, 0, 2, 0, 15.891],
#        [22, 0, 0, 1, 22.818],
#        [59, 0, 2, 0, 13.884],
#        [20, 0, 1, 1, 11.686],
#        [36, 0, 0, 1, 15.49],
#        [18, 0, 0, 0, 37.188],
#        [57, 0, 2, 1, 25.893],
#        [70, 1, 0, 0, 9.849],
#        [47, 1, 0, 0, 10.403],
#        [65, 1, 0, 1, 34.997],
#        [64, 1, 0, 1, 20.932],
#        [58, 1, 0, 0, 18.991],
#        [23, 1, 0, 0, 8.011],
#        [72, 1, 1, 0, 16.31],
#        [72, 1, 1, 0, 6.769],
#        [46, 0, 0, 0, 34.686],
#        [56, 0, 1, 0, 11.567],
#        [16, 1, 1, 0, 12.006],
#        [52, 1, 2, 0, 9.894],
#        [23, 1, 2, 1, 14.02],
#        [40, 0, 1, 1, 11.349]], dtype=object)

# %% [markdown]
# # Encode dependent variable (Y)

# %%
y = le.fit_transform(y)
y
# Out:
# array([4, 2, 2, 3, 4, 3, 4, 2, 4, 4, 2, 4, 4, 4, 3, 4, 3, 0, 2, 4, 4, 4,
#        4, 4, 4, 4, 4, 3, 4, 4, 3, 1, 3, 4, 3, 3, 0, 3, 3, 3, 4, 1, 4, 3,
#        3, 3, 0, 2, 4, 4, 4, 3, 4, 4, 1, 2, 1, 4, 3, 4, 4, 0, 4, 3, 1, 4,
#        0, 3, 4, 4, 1, 4, 3, 4, 4, 4, 0, 4, 0, 3, 1, 3, 2, 0, 2, 1, 3, 4,
#        4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 0, 0, 2, 3, 4, 3, 3, 4, 1, 4,
#        0, 3, 3, 3, 3, 4, 3, 3, 0, 4, 4, 4, 4, 4, 1, 4, 4, 3, 4, 3, 4, 4,
#        3, 4, 4, 3, 1, 0, 1, 3, 0, 4, 1, 4, 0, 3, 3, 0, 3, 2, 0, 1, 3, 3,
#        4, 2, 0, 4, 2, 3, 3, 1, 3, 4, 4, 4, 4, 3, 4, 0, 3, 3, 4, 4, 0, 4,
#        0, 4, 4, 4, 4, 3, 3, 4, 4, 4, 1, 0, 4, 4, 4, 0, 4, 2, 4, 2, 2, 3,
#        3, 3], dtype=int64)

# %% [markdown]
# # Split the dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
x_test
# Out:
# array([[36, 1, 1, 1, 11.424],
#        [16, 0, 0, 1, 15.516],
#        [18, 0, 2, 1, 8.75],
#        [59, 0, 1, 0, 10.444],
#        [47, 1, 1, 1, 33.542],
#        [51, 1, 0, 0, 18.295],
#        [18, 0, 0, 1, 24.276],
#        [28, 0, 2, 0, 12.879],
#        [42, 1, 0, 1, 12.766],
#        [66, 0, 2, 1, 8.107],
#        [29, 1, 0, 0, 12.856],
#        [20, 0, 1, 1, 11.686],
#        [38, 1, 1, 0, 18.295],
#        [19, 0, 0, 0, 13.313],
#        [70, 1, 0, 0, 9.849],
#        [25, 1, 2, 0, 19.011],
#        [65, 1, 0, 1, 11.34],
#        [55, 1, 2, 1, 7.261],
#        [32, 0, 1, 0, 9.712],
#        [54, 1, 2, 0, 24.658],
#        [53, 0, 0, 1, 12.495],
#        [69, 1, 1, 1, 11.455],
#        [61, 0, 1, 1, 7.34],
#        [42, 0, 1, 1, 29.271],
#        [68, 0, 2, 1, 27.05],
#        [38, 0, 1, 1, 29.875],
#        [47, 0, 1, 0, 10.067],
#        [17, 1, 2, 1, 10.832],
#        [19, 0, 0, 1, 25.969],
#        [49, 1, 1, 1, 13.598],
#        [43, 1, 1, 1, 19.368],
#        [23, 1, 1, 0, 7.298],
#        [26, 0, 1, 0, 14.16],
#        [26, 1, 1, 1, 20.909],
#        [49, 1, 0, 1, 8.7],
#        [22, 1, 0, 1, 28.294],
#        [74, 1, 1, 1, 11.939],
#        [35, 0, 0, 0, 12.894],
#        [16, 1, 0, 1, 19.007],
#        [36, 0, 0, 0, 11.198]], dtype=object)
